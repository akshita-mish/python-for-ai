# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# Creating a DataFrame

# %%
data={
    "name":["akshita","anjali","himanshu"],
    "age":[19,22,21],
    "subject":["Maths","English","Arts"]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#        name  age  subject
# 0   akshita   19    Maths
# 1    anjali   22  English
# 2  himanshu   21     Arts

# %%
data=[
    ["Akshita" ,19,200000],
    ["shreyansh",20,200000],
    ["Ranbir",25,300000]
]
df=pd.DataFrame(data)
df
col=["Name","Age","Salary"]
df=pd.DataFrame(data,columns=col)
df
# Out:
#         Name  Age  Salary
# 0    Akshita   19  200000
# 1  shreyansh   20  200000
# 2     Ranbir   25  300000

# %% [markdown]
# Selection and Indexing of Columns

# %%
df[["Name","Age"]]
# Out:
#         Name  Age
# 0    Akshita   19
# 1  shreyansh   20
# 2     Ranbir   25

# %%
df["designation"]=["Engineer","Writer","Painter"]

# %%
df
# Out:
#         Name  Age  Salary designation
# 0    Akshita   19  200000    Engineer
# 1  shreyansh   20  200000      Writer
# 2     Ranbir   25  300000     Painter

# %%
df.drop("designation",axis=1)
# Out:
#         Name  Age  Salary
# 0    Akshita   19  200000
# 1  shreyansh   20  200000
# 2     Ranbir   25  300000

# %%
df
# Out:
#         Name  Age  Salary designation
# 0    Akshita   19  200000    Engineer
# 1  shreyansh   20  200000      Writer
# 2     Ranbir   25  300000     Painter

# %%
df.drop(["designation"],axis=1,inplace=True)

# %%
df
# Out:
#         Name  Age  Salary
# 0    Akshita   19  200000
# 1  shreyansh   20  200000
# 2     Ranbir   25  300000

# %% [markdown]
# Selecting rows

# %%
df.loc[0]
# Out:
# Name      Akshita
# Age            19
# Salary     200000
# Name: 0, dtype: object

# %% [markdown]
# Index location (iloc)

# %%
df.iloc[2]
# Out:
# Name      Ranbir
# Age           25
# Salary    300000
# Name: 2, dtype: object

# %% [markdown]
# Conditional selection

# %%
# i want to see person below the age of 20 or equal to 20 
df[df["Age"]<=20]
# Out:
#         Name  Age  Salary
# 0    Akshita   19  200000
# 1  shreyansh   20  200000

# %%
# i want to se person below 20 and called akshita 
df[(df["Name"]=="Akshita") & (df["Age"]<=20)]
# Out:
#       Name  Age  Salary
# 0  Akshita   19  200000
