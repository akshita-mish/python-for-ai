# %%
import numpy as np
import pandas as pd

# %%
labels=["a","b","c","d"]
my_list=[1,2,3,4]
pd.Series(my_list)
pd.Series(my_list,labels)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
d={"a":1,"b":2,1:6}
pd.Series(d)
# Out:
# a    1
# b    2
# 1    6
# dtype: int64
